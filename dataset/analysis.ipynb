# %%
import polars as pl

# %%
train = pl.read_parquet("C:\Coding\code-review-tune\dataset\github_codereview_test.parquet")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\prath\AppData\Local\Temp\ipykernel_22468\1422320059.py:1: SyntaxWarning: invalid escape sequence '\C'
#   train = pl.read_parquet("C:\Coding\code-review-tune\dataset\github_codereview_test.parquet")

# %%
train[0].rows()
# Out:
# [('import json\nimport pathlib\nimport typer\n\nfrom gpt_engineer.chat_to_files import to_files\nfrom gpt_engineer.ai import AI\nfrom gpt_engineer.steps import STEPS\nfrom gpt_engineer.db import DB, DBs\n\n\napp = typer.Typer()\n\n\n@app.command()\ndef chat(\n    project_path: str = typer.Argument(None, help="path"),\n    run_prefix: str = typer.Option(\n        "",\n        help="run prefix, if you want to run multiple variants of the same project and later compare them",\n    ),\n    model: str = "gpt-4",\n    temperature: float = 0.1,\n):\n    app_dir = pathlib.Path(__file__).parent.parent\n    if project_path is None:\n        project_path = str(app_dir / "example")\n\n    input_path = project_path\n    memory_path = pathlib.Path(project_path) / (run_prefix + "memory")\n    workspace_path = pathlib.Path(project_path) / (run_prefix + "workspace")\n\n    ai = AI(\n        model=model,\n        temperature=temperature,\n    )',
# ...
